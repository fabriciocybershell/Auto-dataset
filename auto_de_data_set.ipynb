# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriciocaetano/redirect/blob/main/auto_de_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **olá :D, esta é uma ferramenta que ajuda na criação de datasets vocais, vamos começar ?**
#
# 1-⁰ rode a célula abaixo para instalar as dependências mínimas para eu funcionar.

# %%
# !apt install sox ffmpeg youtube-dl
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# The following additional packages will be installed:
#   avahi-daemon bind9-host geoclue-2.0 geoip-database gstreamer1.0-plugins-base
#   iio-sensor-proxy libavahi-core7 libavahi-glib1 libbind9-160 libbrotli1
#   libcap2-bin libcdparanoia0 libdaemon0 libdns1100 libdvdnav4 libdvdread4
#   libgeoclue-2-0 libgeoip1 libgl1-mesa-glx libgstreamer-plugins-base1.0-0
#   libgstreamer1.0-0 libhyphen0 libisc169 libisccc160 libisccfg160 libldb1
#   liblua5.2-0 liblwres160 libmagic-mgc libmagic1 libmbim-glib4 libmbim-proxy
#   libmm-glib0 libnl-genl-3-200 libnss-mdns libopencore-amrnb0
#   libopencore-amrwb0 liborc-0.4-0 libpam-cap libqmi-glib5 libqmi-proxy
#   libqt5positioning5 libqt5qml5 libqt5quick5 libqt5sensors5 libqt5webchannel5
#   libqt5webkit5 libsmbclient libsox-fmt-alsa libsox-fmt-base libsox3
# ...

# %% [markdown]
# **2-⁰ downlaod dos dados**
# você tem 4 formas de fazer isso:
#
# -a primeira é enviar seus arquivos para o colab, pode ser em qualquer lugar, seja de forma separada ou compactada em zip ou rar, ;D eu me viro.
#
# -a segunda é me enviar os links do youtube, sound cloud, tidal, spotfy ou links diretos do arquivo de mídia do site em questão, pode ser em qualquer formato, pois .... eu me viro ;D
#
# -a terceira é: insira o nome no campo de "nome", selecione o tópico do que busca, e ... eu me viro para procurar, baixar e converter tudinho ;D
#
# -e a quarta é: nada, o que pode ser melhor do que isso tudo ?
